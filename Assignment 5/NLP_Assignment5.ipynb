# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize

# %%
def get_synonyms(word):
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)

# %%
def get_antonyms(word):
    antonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    return list(antonyms)

# %%
def get_hypernyms(word):
    hypernyms = set()
    for syn in wn.synsets(word):
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    return list(hypernyms)

# %%
def analyze_text_semantics(text):
    tokens = word_tokenize(text.lower())
    results = {}

    for word in tokens:
        if word.isalpha():
            results[word] = {
                "synonyms": get_synonyms(word),
                "antonyms": get_antonyms(word),
                "hypernyms": get_hypernyms(word)
            }
    return results

# %%
text = "The quick brown fox jumps over the lazy dog."

semantic_info = analyze_text_semantics(text)

for word, relations in semantic_info.items():
    print(f"\nWord: {word}")
    print("Synonyms:", relations["synonyms"][:5])
    print("Antonyms:", relations["antonyms"])
    print("Hypernyms:", relations["hypernyms"])
# Out:
# Word: the
# Synonyms: []
# Antonyms: []
# Hypernyms: []
#
# Word: quick
# Synonyms: ['agile', 'flying', 'ready', 'nimble', 'speedy']
# Antonyms: []
# Hypernyms: ['area']
#
# Word: brown
# Synonyms: ['dark-brown', 'Brown_University', 'brownness', 'browned', 'embrown']
# Antonyms: []
# Hypernyms: ['cook', 'chromatic_color', 'color']
#
# Word: fox
# Synonyms: ['Fox', 'George_Fox', 'discombobulate', 'bedevil', 'fox']
# Antonyms: []
# Hypernyms: ['algonquian', 'fur', 'be', 'spot', 'deceiver', 'deceive', 'canine']
#
# Word: jumps
# Synonyms: ['jumping', 'startle', 'rise', 'jump_out', 'spring']
# Antonyms: []
# Hypernyms: ['change', 'wax', 'switch', 'look', 'travel', 'dive', 'start', 'descent', 'move', 'neglect', 'reflex', 'enter', 'increase', 'assail', 'propulsion', 'transition']
#
# Word: over
# Synonyms: ['all_over', 'concluded', 'over', 'complete', 'ended']
# Antonyms: []
# Hypernyms: ['part']
#
# Word: lazy
# Synonyms: ['work-shy', 'indolent', 'slothful', 'faineant', 'lazy']
# Antonyms: []
# Hypernyms: []
#
# Word: dog
# Synonyms: ['track', 'cad', 'chase_after', 'hound', 'blackguard']
# Antonyms: []
# Hypernyms: ['catch', 'unpleasant_woman', 'villain', 'domestic_animal', 'support', 'sausage', 'pursue', 'canine', 'chap']

# %%
word = "happy"
print("Synonyms:", get_synonyms(word))
print("Antonyms:", get_antonyms(word))
print("Hypernyms:", get_hypernyms(word))
# Out:
# Synonyms: ['happy', 'felicitous', 'well-chosen', 'glad']
# Antonyms: ['unhappy']
# Hypernyms: []
